# %% [markdown]
# # This is a Jupyter Notebook
#
# - ...
# - ...

# %% [markdown]
# ## Linear Algebra

# %%
import numpy as np
x = np.array([1, 2, 3])
y = np.array([5, 2.2, -1])
# Out:
# 6.4000000000000004

# %%
x, y
# Out:
# (array([1, 2, 3]), array([ 5. ,  2.2, -1. ]))

# %%
x + y
# Out:
# array([ 6. ,  4.2,  2. ])

# %%
x.dot(y)
# Out:
# 6.4000000000000004

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt

# %%
a = np.linspace(0, 3 * np.pi, 1000)
b = a * np.sin(a)

# %%
plt.grid()
plt.plot(a, b)

# %% [markdown]
# ## Programming

# %%
def func1(a, b):
    return a + 2*b

# %%
func1(4, 5)
# Out:
# 14

# %%
for i in range(3):
    for j in range(5):
        z = func1(i, j)
        print("func1({i}, {j}) = {z}".format(i = i, j = j, z = z))
# Out:
# func1(0, 0) = 0
# func1(0, 1) = 2
# func1(0, 2) = 4
# func1(0, 3) = 6
# func1(0, 4) = 8
# func1(1, 0) = 1
# func1(1, 1) = 3
# func1(1, 2) = 5
# func1(1, 3) = 7
# func1(1, 4) = 9
# func1(2, 0) = 2
# func1(2, 1) = 4
# func1(2, 2) = 6
# func1(2, 3) = 8
# func1(2, 4) = 10
